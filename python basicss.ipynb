# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
a =10

# %%
a
# Out:
# 10

# %%
ran = 20

# %%
ran
# Out:
# 20

# %%
a+ran
# Out:
# 30

# %%
type(a)
# Out:
# int

# %%
b = 2.05

# %%
type(b)
# Out:
# float

# %%
c = 45.99

# %%
type(c)
# Out:
# float

# %%
d = "Ranveer"

# %%
type(d)
# Out:
# str

# %%
e = 'this is my first class'

# %%
type(e)
# Out:
# str

# %%
n = True

# %%
type(n)
# Out:
# bool

# %%
m = False

# %%
type(m)
# Out:
# bool

# %%
n+m
# Out:
# 1

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
ran = 5+8j

# %%
type(v)
# Out:
# complex

# %%
ran.real
# Out:
# 5.0

# %%
ran.imag
# Out:
# 8.0

# %% [raw]
# ran

# %%
print("my name is ranveer")
# Out:
# my name is ranveer

# %%
print(a)
# Out:
# 10

# %%
print(ran)
# Out:
# (5+8j)

# %%
s = "pwskills"

# %%
type(s)
# Out:
# str

# %%
s[1]
# Out:
# 'w'

# %%
s[4]
# Out:
# 'i'

# %%
s[-4]
# Out:
# 'i'

# %%
s[0:3]
# Out:
# 'pws'

# %%
s[0:2]
# Out:
# 'pw'

# %%
s[0:8:2]
# Out:
# 'psil'

# %%
s[::2]
# Out:
# 'psil'

# %%
s[2::2]
# Out:
# 'sil'

# %%
s[2::1]
# Out:
# 'skills'

# %%
s[:: 1]
# Out:
# 'pwskills'

# %%
s[2:7:-1]
# Out:
# ''

# %%
s[8:0]
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'slliksw'

# %%
s[-2:-8:1]
# Out:
# ''

# %%
s[::-1]
# Out:
# 'sllikswp'

# %%
c = 200

# %%
s1 = "this is my string class"

# %%
len(s1)
# Out:
# 23

# %%
s1.find('s')
# Out:
# 3

# %%
s1.find('i')
# Out:
# 2

# %%
s1.find("is")
# Out:
# 2

# %%
s1.find("iS")
# Out:
# -1

# %%
s1.count('s')
# Out:
# 5

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.count('st')
# Out:
# 1

# %%
s1.count('z')
# Out:
# 0

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s2 = 'THIS IS MY STRING CLASS'

# %%
s1.lower()
# Out:
# 'this is my string class'

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.title()
# Out:
# 'This Is My String Class'

# %%
s1.capitalize()
# Out:
# 'This is my string class'

# %%
s
# Out:
# 'pwskills'

# %%
s + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 s + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s + " ran"
# Out:
# 'pwskills ran'

# %%
s + '2'
# Out:
# 'pwskills2'

# %%
s + str(1)
# Out:
# 'pwskills1'

# %%
s * 3
# Out:
# 'pwskillspwskillspwskills'

# %%
'ran' *4
# Out:
# 'ranranranran'

# %%
'ran' / 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 'ran' / 4
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
"don't do copy and paste in my class"
# Out:
# "don't do copy and paste in my class"

# %%
'dont" do copy and paste in my class'
# Out:
# 'dont" do copy and paste in my class'

# %%
"""This is my first class for programming
i have learn variable , data type , string , int , boolean , complex number 
i have seen some example of string slicing and indexing
i have gone though some of the string inbuild function
apart from that i am trying to practice in my system
but some of us in our class are not excuting code and still they are answering which is bad"""
# Out:
#   Cell In[72], line 1
#     """This is my first class for programming
#     ^
# IndentationError: unexpected indent
