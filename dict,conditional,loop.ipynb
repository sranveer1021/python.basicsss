# %%
d ={}

# %%
type(d)
# Out:
# dict

# %%
d1 = {"key" : "ranveer"}

# %%
d1
# Out:
# {'key': 'ranveer'}

# %%
d2 = {"name" : "Ranveer" , "email" : "ranveersingh21july@gmail.com" , "number" : 7301414535 }

# %%
d2
# Out:
# {'name': 'Ranveer',
#  'email': 'ranveersingh21july@gmail.com',
#  'number': 7301414535}

# %%
d3 = {3234 : "ranv" , '_war' : " singh" , True : 232425}

# %%
d3
# Out:
# {3234: 'ranv', '_war': ' singh', True: 232425}

# %%
d3[3234]
# Out:
# 'ranv'

# %%
d3[True]
# Out:
# 232425

# %%
d3[1]
# Out:
# 232425

# %%
d4 = {"name" : "ranveer" , "mail_id" : "ranveersingh.com" ,  "name" :"ashirvad"}

# %%
d4
# Out:
# {'name': 'ashirvad', 'mail_id': 'ranveersingh.com'}

# %%
d4['name']
# Out:
# 'ashirvad'

# %%
d5 = {"company" : "Pwskills" , "course" : ["web dev" ,"Data science" , "java with dsa system design"]}

# %%
d5
# Out:
# {'company': 'Pwskills',
#  'course': ['web dev', 'Data science', 'java with dsa system design']}

# %%
d5["course"]
# Out:
# ['web dev', 'Data science', 'java with dsa system design']

# %%
d5["course"][2]
# Out:
# 'java with dsa system design'

# %%
d6 = {"number" : [2,34,3,34,34] , "assignment" : (1,2,3,4,5,6) , "launch_date" : {28,12,14} , "class_time" : {"web_dev": 8 , "Data science masters" : 8 , "java with dsa and system design" : 7}}

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7}}

# %%
d6['class_time']['java with dsa and system design']
# Out:
# 7

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7}}

# %%
d6["mentor"] = ["sudhanshu","krish","anurag","hayder"]

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
del d6['number']

# %%
d6
# Out:
# {'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
list (d6.keys())
# Out:
# ['assignment', 'launch_date', 'class_time', 'mentor']

# %%
list(d6.values())
# Out:
# [(1, 2, 3, 4, 5, 6),
#  {12, 14, 28},
#  {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  ['sudhanshu', 'krish', 'anurag', 'hayder']]

# %%
list(d6.items())
# Out:
# [('assignment', (1, 2, 3, 4, 5, 6)),
#  ('launch_date', {12, 14, 28}),
#  ('class_time',
#   {'web_dev': 8,
#    'Data science masters': 8,
#    'java with dsa and system design': 7}),
#  ('mentor', ['sudhanshu', 'krish', 'anurag', 'hayder'])]

# %%
marks = int(input("enter your marks : "))
if marks >= 80:
      print("you will be a part of A0 batch")
elif marks >= 60 and marks< 80:
      print("you will be a part of A1 batch")
elif marks >= 40 and marks< 60:
      print("you will be a part of A2 batch")
else :
   print("you will be a part of A3 batch")

# %%
10>=80
# Out:
# False

# %%
marks

# %%
price = int(input("enter price "))
if price > 1000:
   print("i will not purchase")
else :
   print("i will purchase")

# %%
price = int(input("enter price" ))
if price > 1000:
   print("i will not purchase")
   if price >5000:
   print("this is too much ")
elif price < 2000:
    print("its ok")
elif price < 1000:
  print("i will purchase")
else:
print("not interested")
# Out:
#   Cell In[1], line 2
#     if price > 1000;
#                    ^
# SyntaxError: invalid syntax

# %%
l =[ 1,2,3,4,5,6,7,8]

# %%
l[0] +1
# Out:
# 2

# %%
l1= []

# %%
l1.append(l[0] +1)

# %%
l1
# Out:
# [2]

# %%
l = [1,2,3,4,5,6,7,8]

# %%
l1 = []
for i in l :
    print(i+1)
    l1.append(i+1)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l = [ "ranveer" , "singh" , "pwskills" , "course"]

# %%
l1 = []
for i in l :
    print(i)
    l1.append(i.upper())
# Out:
# ranveer
# singh
# pwskills
# course

# %%
l1
# Out:
# ['RANVEER', 'SINGH', 'PWSKILLS', 'COURSE']

# %%
l = [1,2,3,4,5,6,"ranv","singh",343,243,234,"abc"]

# %%
l1_num = []
l2_str = []
for i in l :
    if type(i) == int or type(i) == float :
        l1_num.append(i)
    else:
        l2_str.append(i)

# %%
l1_num
# Out:
# [1, 2, 3, 4, 5, 6, 343, 243, 234]

# %%
l2_str
# Out:
# ['ranv', 'singh', 'abc']
